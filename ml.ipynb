# %% [markdown]
# <a href="https://colab.research.google.com/github/YashaswiniR4/AI-For-Bharat/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import mnist

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %%
# Flatten images
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

print("New shape:", X_train.shape)
# Out:
# New shape: (60000, 784)

# %%
from sklearn import svm

# Create model (RBF kernel)
model = svm.SVC(kernel='rbf')

# Train model
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9792

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 973    0    1    0    0    2    1    1    2    0]
#  [   0 1126    3    1    0    1    1    1    2    0]
#  [   6    1 1006    2    1    0    2    7    6    1]
#  [   0    0    2  995    0    2    0    5    5    1]
#  [   0    0    5    0  961    0    3    0    2   11]
#  [   2    0    0    9    0  871    4    1    4    1]
#  [   6    2    0    0    2    3  944    0    1    0]
#  [   0    6   11    1    1    0    0  996    2   11]
#  [   3    0    2    6    3    2    2    3  950    3]
#  [   3    4    1    7   10    2    1    7    4  970]]

# %%
# Linear SVM
linear_model = svm.SVC(kernel='linear')
linear_model.fit(X_train, y_train)

y_pred_linear = linear_model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Linear SVM Accuracy:", accuracy_score(y_test, y_pred_linear))
# Out:
# Linear SVM Accuracy: 0.9404

# %%
import matplotlib.pyplot as plt
import numpy as np

# Pick a random image
index = np.random.randint(0, len(X_test))

# Show image
plt.imshow(X_test[index].reshape(28,28), cmap='gray')
plt.title("Actual: " + str(y_test[index]))
plt.show()

# Predict
prediction = model.predict([X_test[index]])
print("Predicted:", prediction[0])
# Out:
# Predicted: 1

# %%
for i in range(5):
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(f"Actual: {y_test[i]}")
    plt.show()

    print("Predicted:", model.predict([X_test[i]])[0])
    print("------")
# Out:
# Predicted: 7
# ------
# Predicted: 2
# ------
# Predicted: 1
# ------
# Predicted: 0
# ------
# Predicted: 4
# ------

# %%
import matplotlib.pyplot as plt

# Show 5 predictions
for i in range(5):
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(f"Actual: {y_test[i]} | Predicted: {model.predict([X_test[i]])[0]}")
    plt.axis('off')
    plt.show()

# %%
import joblib

joblib.dump(model, "digit_model.pkl")
# Out:
# ['digit_model.pkl']

# %%
num = int(input("Enter index (0-9999): "))

plt.imshow(X_test[num].reshape(28,28), cmap='gray')
plt.show()

print("Prediction:", model.predict([X_test[num]])[0])
# Out:
# Enter index (0-9999): 54
# Prediction: 6
